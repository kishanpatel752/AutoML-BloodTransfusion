# %% [markdown]
# ## Problem Statement
#  Blood transfusions are a critical aspect of the medical industry, and the timely availability of blood is crucial for saving lives. However, the manual process of blood transfusions can be time-consuming and result in delays that may cause adverse consequences. Automating the blood transfusion supply chain through machine learning techniques can improve the efficiency of blood banks and health agencies in organizing blood donations.
#
# The aim of this research is to predict the likelihood of individuals donating blood in future blood donation camps based on their blood donation history. To achieve this objective, we will use a publicly available dataset of blood donations and train multiple machine learning models to identify the factors that influence an individual's decision to donate blood. We will then optimize the parameters of the models and evaluate their performance using appropriate metrics.

# %% [markdown]
# #### Prospective Outcomes
# The results of this research will contribute to the development of a predictive model that can be integrated into the blood donation supply chain to improve its effectiveness. This model will help blood banks and health agencies to make informed decisions about organizing blood donation camps and identifying potential donors.
#
# Overall, this research will have significant implications for the medical industry and can potentially save lives by ensuring the timely availability of blood for transfusions.

# %% [markdown]
# ## Literature Review
#
# #### **Machine Learning Prediction and Outcomes**
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# ### **Research Paper 1**
# **A survey on machine learning algorithms for the blood donation supply chain - https://iopscience.iop.org/article/10.1088/1742-6596/1362/1/012124/pdf**
#
# **Aim:**
# The aim of this documentation is to provide a comprehensive overview of the machine learning techniques that have been applied in the context of blood donation supply chain management. The objective is to present the advantages and disadvantages of each technique to help stakeholders in the healthcare industry make informed decisions about which machine learning approach to adopt for their specific needs. By summarizing the latest research in this field, this document aims to provide a useful reference for practitioners, researchers, and policymakers working to optimize blood donation supply chain management using machine learning
#
# **Observations & Results:** In the beginning, they used a logistic regression model that produces a donation score but overfit the problem. Then, to provide similar and superior performing models, they used Artificial Neural Networks and Decision trees, respectively. They produce outcomes that are very similar to one another. For the accuracy test of donor group classification, they tried a Multilayer Perceptron with backpropagation and were informed that ANN was found to be a more appropriate model. They correctly identified 88% of the candidates as blood donors and correctly identified 81.7% of the others as non-donors, with recall and precision scores of 41.6% and 53.8%, respectively. This model's overall accuracy was 76.25%. An improved model for these calculations was found to be ANN.
#
# Their final point of comparison is between SVM and ANN. Least squares SVM is a type of SVM that is utilised. They have a number of characteristics that are noteworthy when compared to the dataset's total number of data points.
#
# **Conclusion:** After experimenting with different machine learning algorithms, researchers have come to the conclusion that methods like ANN, SVM, and decision trees are essential for creating a reliable and fair system for locating and contacting potential blood donors.
#
# **References:**
#
# Subramanian Mahadevan et al 2019 J. Phys.: Conf. Ser. 1362 012124
#
# Raj A, Gupta A & Selvaraj P. 2018. “Predicting Donor’s Likelihood of donating blood given various factors”. International Journal of Pure and Applied Mathematics.118.
#
# Boonyanusith W, Jittamai P. “Blood donor classification using neural network and decision tree techniques”. In Proceedings of the World Congress on Engineering and Computer Science 2012 (Vol. 1, pp. 499-503).
#
# Chen HC, Wee HM, Hsieh YH. Optimal supply chain inventory decision using artificial neural network. In 2009 WRI Global Congress on Intelligent Systems 2009 May 19 (Vol.4, pp. 130-134). IEEE.
#
# Sun A, Zhao T, Chen J, Chang J. Comparative Study: Common ANN and LS-SVM Exchange Rate Performance Prediction. Chinese Journal of Electronics. 2018 May 1;27(3):561-4.
#
# **Predictions from Paper vs Expectations:**
# The supply chain for blood donations was nicely surveyed in this academic paper's section on machine learning algorithms. In particular, they emphasise the issue of The blood donation supply chain is under a lot of pressure because of the increasing demand for blood and the decline in donation rates. They then compared the benefits and drawbacks of the different machine learning techniques that have been used in this domain and provided an overall summary of each.
#
# After reading this paper, we can state that after attempting different machine learning algorithms, their prediction matched with the expectations. As a consequence, there would be less complexity associated with transfusions and a higher likelihood of finding the ideal donor.
#
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# ### **Research Paper 2**
# **Knowledge discovery on RFM model using Bernoulli sequence: https://www.sciencedirect.com/science/article/abs/pii/S0957417408004508?via%3Dihub**
#
# **Aim:**
# The aim of the paper "Knowledge discovery on RFM model using Bernoulli sequence" is to propose and evaluate a novel approach for customer segmentation (blood donors in this case) and churn prediction in the respective industry by combining the RFM model with a Bernoulli sequence-based method.
#
# **Observations & Results:** The combination of the RFM model and a Bernoulli sequence-based method is a promising approach for customer segmentation and churn prediction in the respective industry. The proposed approach effectively identified different donors with distinct donation behavior patterns. The proposed approach outperformed traditional methods in predicting donor churn.
#
# **Conclusion:** The results of the study suggest that the proposed approach is a promising approach for donor analytics in the industry and has the potential to improve donors behaviour and churn prediction accuracy.
#
# **Predictions from paper vs Expectations:** This paper is not directly relevant to our research.
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#
#
# ### **Research Paper 3**
# **PREDICTING BLOOD DONATIONS USING MACHINE LEARNING TECHNIQUES-http://matthewalanham.com/Students/2017_MWDSI_Final_Bahel.pdf**
#
# **Aim:**
# Deepti Bahel, Prerana Ghosh, Arundhyoti Sarkar, and Matthew A. Lanham have written a research paper with the primary objective of identifying the most effective machine learning technique that can accurately predict the number of donors who meet the criteria for blood donation, given the increasing number of transfusions resulting from accidents, illnesses, and surgeries.
#
# **Observations:** Since the problem involves classification, the researchers utilized various classification techniques, including SVM, ANN, CART, C5.0, Logistic Regression, Logit (Bagging & Boosting), LDA, and Random Forest. They also employed 5-fold and 10-fold cross-validation on some of the models, as this would enable the model to learn from multiple sample datasets, rather than just one.
#
# **Result & Conclusion:** The logistic regression model with 5-fold cross-validation demonstrated the highest performance among all the algorithms with a test set AUC of 72.6%. However, the main focus of the research was to identify individuals who would be interested in donating blood regularly, and thus sensitivity was prioritized over other metrics. Therefore, a clustered SVM model with 98.4% sensitivity was recommended by the researchers.
#
# **References:**
# Ashoori, M., et al. (2017). "Exploring Blood Donors’ Status Through Clustering: A Method to Improve the Quality of Services in Blood Transfusion Centers." Journal of Knowledge & Health 11(4): page: 73-82.
#
# Bhardwaj, A., et al. (2012). "Data mining techniques and their implementation in blood bank sector–a review." International Journal of Engineering Research and Applications (IJERA) 2(4): 1303-1309.
#
# Godin, G., et al. (2007). "Determinants of repeated blood donation among new and experienced blood donors." Transfusion 47(9): 1607-1615
#
# Santhanam, T. and S. Sundaram (2010). "Application of CART algorithm in blood donors classification." Journal of Computer Science 6(5): 548.
#
# Veldhuizen, I., et al. (2011). "Exploring the dynamics of the theory of planned behavior in the context of blood donation: does donation experience make a difference?" Transfusion 51(11): 2425-2437.
#
# **Predictions from Paper vs Expectations:**
# Following the application of the Decision Tree, Logistic Regression, and SVM algorithms, our accuracy of the model (however used RF and LR) almost matches the accuracy of algorithms used in the research paper. As they have used the classification algorithms for the classification problem, they have met our expectation.

# %% [markdown]
# #### **Python Code**

# %% [markdown]
# #### **Attributes**
# R (Recency - months since the last donation)
#
# F (Frequency - total number of donation)
#
# M (Monetary - total blood donated in c.c.)
#
# T (Time - months since the first donation)
#
# a binary variable representing whether he/she donated blood in March 2007 (1 stands for donating blood; 0 stands for not donating blood)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore', category=FutureWarning)
warnings.filterwarnings('ignore', category=DeprecationWarning)
# %matplotlib inline
df = pd.read_csv("transfusion_data_with_name.csv")
df
# Out:
#      Sr.no                    Name  Recency (months)  Frequency (times)  \
# 0        1  Oluwatobiloba Goulding                 2                 50
# 1        2        Gianluca Herring                 0                 13
# 2        3          Antonia Almond                 1                 16
# 3        4             Sally Sloan                 2                 20
# 4        5             Kelis Hirst                 1                 24
# ..     ...                     ...               ...                ...
# 744    745             Ioana Mccoy                21                  2
# 745    746             Amirah Vang                23                  3
# 746    747            Brent Almond                39                  1
# 747    748         Elena Mccormack                72                  1
# 748    749         Elena Mccormack                72                  1
#
#      Monetary (c.c. blood)  Time (months)  Year  \
# 0                    12500             98  2007
# ...

# %% [markdown]
# This code will rename the column 'whether he/she donated blood in March 2007' to 'donated' in place. The inplace argument is set to True, so the change will be made directly to the DataFrame df.

# %%
df.rename(
    columns = {'whether he/she donated blood in March 2007': 'donated'},
    inplace = True
)

# %% [markdown]
# This code will drop the columns "Sr.no", "Name", "Location_Name", and "Year" from the DataFrame df. The axis argument is set to 1 to specify that the columns should be dropped, rather than the rows.

# %%
df = df.drop(["Sr.no","Name","Location_Name", "Year"], axis = 1)

# %%
df.value_counts("donated")
# Out:
# donated
# 0    571
# 1    178
# dtype: int64

# %%
df.value_counts("Location")
# Out:
# Location
# 3    262
# 2    259
# 1    228
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 749 entries, 0 to 748
# Data columns (total 6 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Recency (months)       749 non-null    int64
#  1   Frequency (times)      749 non-null    int64
#  2   Monetary (c.c. blood)  749 non-null    int64
#  3   Time (months)          749 non-null    int64
#  4   donated                749 non-null    int64
#  5   Location               749 non-null    int64
# dtypes: int64(6)
# memory usage: 35.2 KB

# %%
df.describe()
# Out:
#        Recency (months)  Frequency (times)  Monetary (c.c. blood)  \
# count        749.000000         749.000000             749.000000
# mean           9.590120           5.508678            1377.169559
# std            8.406069           5.837734            1459.433448
# min            0.000000           1.000000             250.000000
# 25%            3.000000           2.000000             500.000000
# 50%            7.000000           4.000000            1000.000000
# 75%           14.000000           7.000000            1750.000000
# max           74.000000          50.000000           12500.000000
#
#        Time (months)     donated    Location
# count     749.000000  749.000000  749.000000
# mean       34.332443    0.237650    2.045394
# std        24.399368    0.425928    0.808095
# min         2.000000    0.000000    1.000000
# 25%        16.000000    0.000000    1.000000
# 50%        28.000000    0.000000    2.000000
# 75%        50.000000    0.000000    3.000000
# ...

# %%
features = df.drop(['donated'], axis = 1)
label = df['donated']

# %%
for i in features.columns:
    sns.barplot(x='donated',y=i,data=df)
    plt.show()

# %% [markdown]
# This distribution plots are used to visualize the distribution of a set of data. It helps in understanding the spread and skewness of the data and can be used to identify any outliers or skewness in the data. This distribution plot typically shows the histogram and density plot of the data, which provides a visual representation of the frequency and probability density of the data.

# %%
#Distribution plot

plt.figure(figsize=(20,20))
col = features.columns
cnt = 1

for i in col:
    plt.subplot(4,3,cnt)
    sns.distplot(features[i], hist_kws=dict(edgecolor='k', linewidth=1, color='black'), color='red')
    cnt+=1
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Admin1\AppData\Local\Temp\ipykernel_10084\4155059741.py:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(features[i], hist_kws=dict(edgecolor='k', linewidth=1, color='black'), color='red')
# C:\Users\Admin1\AppData\Local\Temp\ipykernel_10084\4155059741.py:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %% [markdown]
# This Box plots provide a quick visual representation of the distribution of the data and can be used to identify any skewness, outliers, and variability in the data. They are particularly useful when comparing the distribution of multiple datasets, as they provide a clear visual representation of the differences between the datasets.

# %%
i=1
plt.figure(figsize=(30,80))
for col in df.columns:
    plt.subplot(11,2,i)
    sns.boxplot( df["donated"], df[col])
    plt.ylabel(col,fontsize=25)
    plt.xlabel("donated",fontsize=25)
    i=i+1
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-bd030ed0f109> in <module>
#       3 for col in df.columns:
#       4     plt.subplot(11,2,i)
# ----> 5     sns.boxplot( df["donated"], df[col])
#       6     plt.ylabel(col,fontsize=25)
#       7     plt.xlabel("donated",fontsize=25)
#
# TypeError: boxplot() takes from 0 to 1 positional arguments but 2 were given

# %% [markdown]
# In this heatmap, each cell is colored according to the value of a particular variable, with darker colors indicating higher values and lighter colors indicating lower values. This allows the relationships between the variables to be easily seen and compared. this heatmaps can be used to visualize the correlation between variables, which is useful in identifying variables that are related to each other.

# %%
plt.figure(figsize=(15, 15))
sns.heatmap(df.corr(), annot=True,
           cmap='YlGnBu');

# %% [markdown]
# We can see that the attributes are of different magnitudes and Scaling them in the same magnitude becomes significant to train the machine learning algorithm. Therefore, we are using StandardScaler() from SciKit Learn library to scale the features between 0 to 1.

# %%
from sklearn.preprocessing import StandardScaler

# Assuming your data is stored in a variable called "X"
scaler = StandardScaler()
X_scaled = scaler.fit_transform(features)

# %% [markdown]
# The code below is splitting the features and label datasets into training and testing sets using the train_test_split function from the scikit-learn library. The function splits the data into two parts, with 70% of the data being used for training and 30% being used for testing. The training data will be used to train the machine learning model, while the testing data will be used to evaluate the performance of the model.

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X_scaled, label, train_size=0.7)

# %% [markdown]
# This code defines a function called print_results that takes in an argument results, which is an object containing the results of a grid search or cross-validation operation.

# %%
def print_results(results):
    print('BEST PARAMS: {}\n'.format(results.best_params_))

    means = results.cv_results_['mean_test_score']
    stds = results.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, results.cv_results_['params']):
        print('{} (+/-{}) for {}'.format(round(mean, 3), round(std * 2, 3), params))

# %% [markdown]
# ### Logistic Regression

# %% [markdown]
# This code performs a grid search for the best hyperparameters for a logistic regression model in scikit-learn. It imports the LogisticRegression and GridSearchCV classes, creates a logistic regression model instance, sets up a grid search with 8-fold cross-validation and a range of values for the regularization strength parameter, and fits the model to the training data. The best parameters are then printed.

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV
lr = LogisticRegression()
parameters = {
    'C': [0.001, 0.01, 0.1, 1, 10, 100, 1000]
}
cv = GridSearchCV(lr, parameters, cv= 8)
cv.fit(x_train, y_train)

print(cv.best_params_)
# Out:
# {'C': 0.01}

# %% [markdown]
# The mean_test_score returns an array of the mean test scores (i.e., accuracy) of the model for each set of hyperparameters in the grid search.

# %%
cv.cv_results_['mean_test_score']
# Out:
# array([0.76908508, 0.77674825, 0.77485431, 0.7710373 , 0.76719114,
#        0.76719114, 0.76719114])

# %% [markdown]
# The std_test_score returns an array of the standard deviations of the test scores (i.e., accuracy) of the model for each set of hyperparameters in the grid search.

# %%
cv.cv_results_['std_test_score']
# Out:
# array([0.00464147, 0.01808584, 0.03174348, 0.03552633, 0.03793071,
#        0.03793071, 0.03793071])

# %% [markdown]
# The cv.best_estimator_ returns the best estimator from the grid search. The estimator is the logistic regression model instance with the hyperparameters that resulted in the highest mean test score (i.e., accuracy). This estimator can be used for making predictions on new data.

# %%
cv.best_estimator_
# Out:
# LogisticRegression(C=0.01)

# %% [markdown]
# Now calculate the Area Under the ROC Curve (AUC) for binary classification problems.

# %%
from sklearn.metrics import roc_auc_score
AUC_Score = roc_auc_score(y_test, cv.predict_proba(x_test)[:,1])
AUC_Score
# Out:
# 0.7474937343358397

# %% [markdown]
# ### Random Forest Classifier

# %% [markdown]
# This code block is defining and fitting a Random Forest Classifier model using GridSearchCV for hyperparameter tuning.

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier()
parameters = {
    'n_estimators' : [5, 50, 250],
    'max_depth' : [2, 4, 8, 16, 32, None]
}

CV5 = GridSearchCV(rf, parameters, cv = 8)
CV5.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=8, estimator=RandomForestClassifier(),
#              param_grid={'max_depth': [2, 4, 8, 16, 32, None],
#                          'n_estimators': [5, 50, 250]})

# %% [markdown]
# The purpose of this function is to print the best hyperparameters obtained through the GridSearchCV and the mean and standard deviation of the test scores for each hyperparameter combination.

# %%
print_results(CV5)
# Out:
# BEST PARAMS: {'max_depth': 4, 'n_estimators': 5}
#
# 0.769 (+/-0.031) for {'max_depth': 2, 'n_estimators': 5}
# 0.767 (+/-0.032) for {'max_depth': 2, 'n_estimators': 50}
# 0.769 (+/-0.034) for {'max_depth': 2, 'n_estimators': 250}
# 0.788 (+/-0.068) for {'max_depth': 4, 'n_estimators': 5}
# 0.771 (+/-0.045) for {'max_depth': 4, 'n_estimators': 50}
# 0.773 (+/-0.055) for {'max_depth': 4, 'n_estimators': 250}
# 0.75 (+/-0.068) for {'max_depth': 8, 'n_estimators': 5}
# 0.767 (+/-0.093) for {'max_depth': 8, 'n_estimators': 50}
# 0.781 (+/-0.089) for {'max_depth': 8, 'n_estimators': 250}
# 0.752 (+/-0.073) for {'max_depth': 16, 'n_estimators': 5}
# 0.773 (+/-0.084) for {'max_depth': 16, 'n_estimators': 50}
# 0.769 (+/-0.084) for {'max_depth': 16, 'n_estimators': 250}
# 0.756 (+/-0.083) for {'max_depth': 32, 'n_estimators': 5}
# 0.767 (+/-0.089) for {'max_depth': 32, 'n_estimators': 50}
# 0.773 (+/-0.079) for {'max_depth': 32, 'n_estimators': 250}
# ...

# %% [markdown]
# The below function calculates the prediction for the features using the model and measures the accuracy, precision, and recall of the prediction using the scikit-learn functions accuracy_score, precision_score, and recall_score. The function also measures the latency of the prediction by finding the difference between the start and end time. The results of these calculations are then printed to the console using string formatting.

# %%
def evaluate_model(name, model, features, labels):
    start = time()
    pred = model.predict(features)
    end = time()
    accuracy = round(accuracy_score(labels, pred), 3)
    precision = round(precision_score(labels, pred, average='macro'), 3)
    recall = round(recall_score(labels, pred, average='macro'), 3)
    print('{} -- Accuracy: {} / Precision: {} / Recall: {} / Latency: {}ms'.format(name,
                                                                                   accuracy,
                                                                                   precision,
                                                                                   recall,
                                                                                   round((end - start)*1000, 1)))

# %%
LR = cv.best_estimator_
RF = CV5.best_estimator_

# %% [markdown]
# These two lines of code are setting the Logistic Regression and Random Forest models to their respective best estimators as determined by their grid search cross-validation. The best estimators are the models with the best hyperparameter settings that achieved the highest cross-validation accuracy.

# %%
models={'LR':LR,'RF':RF}
models
# Out:
# {'LR': LogisticRegression(C=0.01),
#  'RF': RandomForestClassifier(max_depth=4, n_estimators=5)}

# %%
import joblib
import pandas as pd
from sklearn.metrics import accuracy_score, precision_score, recall_score
from time import time
for mdl in models:
     evaluate_model(mdl, models[mdl], x_train, y_train)
# Out:
# LR -- Accuracy: 0.777 / Precision: 0.805 / Recall: 0.519 / Latency: 0.0ms
# RF -- Accuracy: 0.815 / Precision: 0.746 / Recall: 0.683 / Latency: 0.0ms

# %% [markdown]
# The evaluate_model function calculates accuracy, precision, recall, and latency (time taken to make predictions) for the given model. The results are then printed in a readable format.

# %% [markdown]
# ### **Machine Learning Solutions**
#
# ##### **How different or similar is your approach as compared to your research papers?**
# > The method we are employing differs slightly from the methods employed in the two study papers. While we have chosen to use the Random Forest model, it has been demonstrated in both research papers that the SVM has the greatest accuracy when compared to the other algorithms.
#
# #### **What algorithm are you proposing to use? Why?**
# > We experimented with various algorithms, including Random Forest and Logistic Regression. We came to the conclusion that RF has a better accuracy than other algorithmic models.As a result, we chose to develop the RF algorithm.
#
# #### **What would be the results?**
# > After using two separate popular algorithms to train the machine learning models, we can say that RF will increase the likelihood that someone will donate blood during the upcoming blood drive or whenever it is needed. These kinds of initiatives would reduce response times and increase costs. There would be a higher chance of discovering the perfect donor, which would lead to fewer transfusion-related complications.

# %% [markdown]
# ### **References**
#
# - Kaggle. (2020, November 9). Working With TPOT. Kaggle. Retrieved April 21, 2022, from https://www.kaggle.com/code/tug004/predicting-blood-transfusion-with-tpot-0-78-auc/data
#
# - Andreas Mitterecker, A. H. (2020, June 28). Transfusion. Retrieved from National Library of Medicine: https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7540018/
#
# - Bell TH, Berta D, Ralley F, Macdonald SJ, McCalden RW, Bourne RB et al (2009) Factors affecting perioperative blood loss and transfusion rates in primary total joint arthroplasty: a prospective analysis of 1642 patients. Can J Surg 52:295–301
#
# - Adalberth G, Byström S, Kolstad K, Mallmin H, Milbrink J (1998) Postoperative drainage of knee arthroplasty is not necessary: a randomized study of 90 patients. Acta Orthop Scand 69:475–478
#
# - Library documentation: https://scikit-learn.org/stable/documentation.html
# API reference: https://scikit-learn.org/stable/modules/classes.html
#
# Logistic Regression:
#
# - scikit-learn documentation: https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LogisticRegression.html
#
# - Introduction to Logistic Regression: https://towardsdatascience.com/logistic-regression-detailed-overview-46c4da4303bc
#
# Random Forest:
# - scikit-learn documentation: https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestClassifier.html
#
# - Introduction to Random Forest: https://towardsdatascience.com/understanding-random-forest-58381e0602d2
#
# GridSearchCV:
# - scikit-learn documentation: https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.GridSearchCV.html
#
# Model evaluation metrics (accuracy, precision, recall):
# - scikit-learn documentation: https://scikit-learn.org/stable/modules/classes.html#module-sklearn.metrics
#
# - Overview of evaluation metrics: https://towardsdatascience.com/accuracy-precision-recall-or-f1-331fb37c5cb9
